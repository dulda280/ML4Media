# %%
import tensorflow as tf
import numpy as np
import matplotlib as plt
import sklearn
import os
import PIL
import PIL.Image
from tensorflow import keras
import tensorflow_datasets as tfds
from tensorflow.keras.applications.resnet50 import ResNet50


path = 'dataset-resized'
classnames = ['cardboard', 'glass', 'metal', 'paper', 'plastic']
dataset = tfds.ImageFolder(path)
ds = dataset.as_dataset(split='train', shuffle_files=True)
print(dataset.info)
tfds.show_examples(ds, dataset.info)

#X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=0.20, random_state=42)
# Out:
# 2022-11-04 11:00:15.771132: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# tfds.core.DatasetInfo(
#     name='image_folder',
#     full_name='image_folder/1.0.0',
#     description="""
#     Generic image classification dataset.
#     """,
#     homepage='https://www.tensorflow.org/datasets/catalog/image_folder',
#     data_path='/Users/sebastian-pc/tensorflow_datasets/image_folder/1.0.0',
#     file_format=tfrecord,
#     download_size=Unknown size,
#     dataset_size=Unknown size,
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#         'image/filename': Text(shape=(), dtype=tf.string),
# ...

# %%
base_model = ResNet50(input_shape = (224, 224, 3), # Shape of our images
include_top = False, # Leave out the last fully connected layer
weights = 'imagenet')
